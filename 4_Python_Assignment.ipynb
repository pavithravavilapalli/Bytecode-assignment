# %% [markdown]
# - Print all elements of a list

# %%
ls=[10,20,30,40,50]
for i in ls:
    print(i)
# Out:
# 10
# 20
# 30
# 40
# 50

# %% [markdown]
# # 2.Print all fruits

# %%
ls=["apple","banana","grapes","mango"]
for i in ls:
    print(i)
# Out:
# apple
# banana
# grapes
# mango

# %% [markdown]
# # 3.Print numbers from 1 to 5

# %%
for i in range(1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# # 4.Find the sum of all numbers (list)

# %%
ls=[10,20,30,40]
sum=0
for i in ls:
  sum=sum+i
  print(sum)
# Out:
# 10
# 30
# 60
# 100

# %% [markdown]
# #5.Count the number of elements (list)

# %%
#Count the number of elements (list)
ls=[10,20,30,40,50,70,90,20,30]
for i in ls:
  length=len(ls)
print(length)
# Out:
# 9

# %% [markdown]
# # 6.Find the average (marks = [70, 80, 90, 60])

# %%
marks=[70,30,50,20,45.36]
total=0
for i in marks:
  total=total+i
  average=total/len(marks)
print(total)
print(average)
# Out:
# 215.36
# 43.072

# %% [markdown]
# # 7.Print even numbers

# %%
ls=[10,21,33,45,50,60,70,80]

for num in ls:
  if num%2==0:
    print("this is even number:",num)
# Out:
# this is even number: 10
# this is even number: 50
# this is even number: 60
# this is even number: 70
# this is even number: 80

# %% [markdown]
# # 8.Print odd numbers

# %%
ls=[10,21,33,45,50,60,70,80]

for num in ls:
  if num!=0:
    print("this is dd number:",num)
# Out:
# this is dd number: 10
# this is dd number: 21
# this is dd number: 33
# this is dd number: 45
# this is dd number: 50
# this is dd number: 60
# this is dd number: 70
# this is dd number: 80

# %% [markdown]
# # 9.**Count** positive numbers

# %%
ls=[10,-20,30,40,-50,67]
for num in ls:
  if num>0:
    print("this is positive number:",num)
# Out:
# this is positive number: 10
# this is positive number: 30
# this is positive number: 40
# this is positive number: 67

# %% [markdown]
# # 10.Print each character

# %%
ls="hello world"
for i in ls:
  print(i)
# Out:
# h
# e
# l
# l
# o
#
# w
# o
# r
# l
# d

# %% [markdown]
# ## 11.Count vowels

# %%
ls="hello world"
vowels="aeiouAEIOU"
count=0
for i in ls:
  if i in vowels:
    count=count+1
print(count)
# Out:
# 3

# %% [markdown]
# # 12.Count uppercase letters

# %%
ls="Hello World"
count=0
for i in ls:
  if i.isupper():
    count=count+1
print(count)
# Out:
# 2

# %% [markdown]
# # 13.Find largest number

# %%
ls=[1,2,4,6,9,23,9,7,38]
for i in ls:
  largest=max(ls)
print(largest)
# Out:
# 38

# %% [markdown]
# # 14.Find smallest number

# %%
ls=[1,2,4,6,9,23,9,7,38]
for i in ls:
  smallest=min(ls)
print(smallest)
# Out:
# 1

# %% [markdown]
# # 15.Print index and value

# %%
ls=[10,20,100,200,300]
for i in range(len(ls)):
  print(i,ls[i])
# Out:
# 0 10
# 1 20
# 2 100
# 3 200
# 4 300

# %% [markdown]
# # 16.Print elements at even positions

# %%
ls=[10,20,100,40,60]
for i in range(len(ls)):
  if i%2==0:
    print(ls[i])
# Out:
# 10
# 100
# 60

# %% [markdown]
# # 17.Print all keys

# %%
dict={"name":"pavi","age":21,"branch":"cse"}
for i in dict.keys():
  print(i)
# Out:
# name
# age
# branch

# %% [markdown]
# # 18.Print all values

# %%
dict={"name":"pavi","age":21,"branch":"cse"}
for i in dict.values():
  print(i)
# Out:
# pavi
# 21
# cse

# %% [markdown]
# # 19.Print key-value pairs

# %%
dict={"name":"pavi","age":21,"branch":"cse"}
for i in dict.items():
  print(i)
# Out:
# ('name', 'pavi')
# ('age', 21)
# ('branch', 'cse')

# %% [markdown]
# # 20.Calculate total sales

# %%
sales={"shirts":100,
       "pants":200,
       "shoes":300}
total_sales=0
for i in sales.values():
  total_sales=total_sales+i
print(total_sales)
# Out:
# 600

# %% [markdown]
# # 21.Find highest sales value

# %%
sales={"shirts":100,
       "pants":200,
       "shoes":300}
for i in sales.values():
  largest=max(sales.values())
print(largest)
# Out:
# 300

# %% [markdown]
# # 22.Count customers with purchases above 1000

# %%
sales={"arjun":100,
       "prem":200,
       "harish":3000
       }
count=0
for i in sales.values():
        if i>1000:
          count=count+1
          print(count)
# Out:
# 1

# %% [markdown]
# # 23.Print products with price greater than 500

# %%
sales={"serum":550,
       "sunscreen":800,
       "lipstick":200,
       "moisturizer":400}
for sales,sale in sales.items():
        if sale>500:
          print(sales)
# Out:
# serum
# sunscreen
