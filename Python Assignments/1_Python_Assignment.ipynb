# %% [markdown]
# Q1.Identify the data type of the following values.
# - a=100
# - b=10.5
# - c="Python"
# - d=True
# - e=4+5j

# %%
a=100
b=10.5
c="Python"
d=True
e=4+5j
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'complex'>

# %% [markdown]
# Q2.Create a variables to store:
# - Your Name
# - Age
# - Salary
# - Is Python Easy?(True/False)

# %%
Name=input("Enter your name:")
age=input("enter youe age:")
salary=input("enter your salary:")
Is_Python_Easy=True
print(Name)
print(age)
print(salary)
print(Is_Python_Easy)
# Out:
# Enter your name:pavi
# enter youe age:21
# enter your salary:1000
# pavi
# 21
# 1000
# True

# %% [markdown]
# Q3.Perform all arthimetic operations on two numbers.
# - a=20
# - b=3

# %%
a=20
b=3
print("addition:",a+b)
print("substraction:",a-b)
print("multiplication:",a*b)
print("division:",a/b)
print("modulus:",a%b)
# Out:
# addition: 23
# substraction: 17
# multiplication: 60
# division: 6.666666666666667
# modulus: 2

# %% [markdown]
# Q4. Compare two numbers.
# - a = 15
# - b = 20

# %%
a=int(input("Enter a value:"))
b =int(input("Enter b value:"))

print("b value is:", a)
print("b value is:",b)


print("Greater than:",a>b )
print("less than:",a<b)
print("Greater than equal to:" , a<=b)
print("Equals to:",a == b)
print ("Modulus:", a!=b)
# Out:
# Enter a value:20
# Enter b value:30
# b value is: 20
# b value is: 30
# Greater than: False
# less than: True
# Greater than equal to: True
# Equals to: False
# Modulus: True

# %% [markdown]
# Q5. Check whether two strings are equal.
# Answer
# - name1 = "Python"
# - name2 = "python"

# %%
name1="Python"
name2="python"
print(name1==name2)
# Out:
# False

# %% [markdown]
# Q6. Create a list and access the first, last, and third elements.
# list_values : ["Apple", "Banana", "Mango", "Orange", "Grapes"]
# - Add "Pineapple" to the list.
# - Insert "Watermelon" at index 1.
# - Remove "Banana" from the list.

# %%
list_values=["apple","banana","mango","orange","grapes"]
print(list_values[0])
print(list_values[-1])
print(list_values[2])
list_values.append("pineapple")
print(list_values)
list_values.insert(1,"watermelon")
print(list_values)
print(list_values.remove("banana"))
print(list_values)
# Out:
# apple
# grapes
# mango
# ['apple', 'banana', 'mango', 'orange', 'grapes', 'pineapple']
# ['apple', 'watermelon', 'banana', 'mango', 'orange', 'grapes', 'pineapple']
# None
# ['apple', 'watermelon', 'mango', 'orange', 'grapes', 'pineapple']

# %% [markdown]
# Q7. Sort the following list. numbers = [50, 20, 80, 10, 40]
# - Reverse sort the list.

# %%
numbers =[50,20,80,10,40]
numbers.sort()
print("ascending order:",numbers)
numbers.sort(reverse=True)
print("descending order:",numbers)
# Out:
# ascending order: [10, 20, 40, 50, 80]
# descending order: [80, 50, 40, 20, 10]

# %% [markdown]
# Q8. Create a tuple and access each elements.
# colors = ("Red", "Blue", "Green", "Black")
# - Find the index of "Green".

# %%
colors = ("Red", "Blue", "Green", "Black")
colors.index("Green")
# Out:
# 2

# %% [markdown]
# Q9. Count the occurrence of 10.
# - Answer
# - numbers = (10, 20, 10, 30, 10)

# %%
numbers = (10, 20, 10, 30, 10)
numbers.count(10)
# Out:
# 3

# %% [markdown]
# Q10. Create a dictionary for a student. (name, age, city)
# - Access the student's name.
# - Add a new key "salary".
# - Update the age.
# - Remove the city key.
# - Display all keys and values separately.

# %%
dict1 ={"Name" : "Pavi",
        "age":21,
        "city":"hyderabad"

      }
print(dict1["Name"])
dict1["salary"]=1000
print(dict1)
dict1["age"]=21
print(dict1)
dict1.pop("city")
print(dict1)
print(dict1.keys())
dict1.values()
# Out:
# Pavi
# {'Name': 'Pavi', 'age': 21, 'city': 'hyderabad', 'salary': 1000}
# {'Name': 'Pavi', 'age': 21, 'city': 'hyderabad', 'salary': 1000}
# {'Name': 'Pavi', 'age': 21, 'salary': 1000}
# dict_keys(['Name', 'age', 'salary'])
# dict_values(['Pavi', 21, 1000])

# %% [markdown]
# Q11. Merge two lists.
# Answer
# - list1 = [10, 20, 30]
# - list2 = [40, 50, 60]

# %%
L1=[10,20,30]
L2=[40,50,60]
L1.extend(L2)
print(L1)
# Out:
# [10, 20, 30, 40, 50, 60]

# %% [markdown]
# Q12. Merge two dictionaries.
# Answer
# - dict1 = {"a": 1, "b": 2}
# - dict2 = {"c": 3, "d": 4}

# %%
dict1={"a":1,"b":2}
dict2={"c":3,"d":4}
dict1.update(dict2)
print(dict1)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}
